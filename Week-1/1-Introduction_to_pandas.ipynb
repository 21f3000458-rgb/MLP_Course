# %% [markdown]
# # Introduction to Pandas
#
# **Learning Objectives:**
#
# * Gain an introduction to the `DataFrame` and `Series` data structures of the *pandas* library
# * Access and manipulate data within a `DataFrame` and `Series`

# %% [markdown]
# [*pandas*](http://pandas.pydata.org/) is a column-oriented data analysis API.
# It's a great tool for handling and analyzing input data, and many ML frameworks
# support *pandas* data structures as inputs.
#
# Although a comprehensive
# introduction to the API would span many pages, the core concepts are fairly
# straightforward, and we'll present them below. For a more complete reference,
# the [*pandas* docs site](http://pandas.pydata.org/pandas-docs/stable/index.html)
# contains extensive documentation and many tutorials. (Note that Colab may use a
# slightly older version number, but the parts of *pandas* covered here are
# unlikely to differ from version to version.)

# %% [markdown]
# Let's import ```pandas``` library

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# The primary data structures in *pandas* are implemented as two classes:
#
#   * **`DataFrame`**, which you can imagine as a relational data table, with rows and named columns.
#   * **`Series`**, which is a single column. Each row can be labeled via an index. A DataFrame contains one or more Series and a name for each Series.
#
# The data frame is a commonly used abstraction for data manipulation. Similar implementations exist in Spark and R.

# %%
from sklearn.datasets import load_diabetes

diabetes = load_diabetes(as_frame=True)
print(type(diabetes['data']))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# ?load_diabetes

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
#     - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %%
df = diabetes['data']

# %% [markdown]
# ## Creating pandas dataframe from series

# %%
cities = pd.Series(['Mumbai', 'Bangalore', 'Chennai', 'Delhi'])
population = pd.Series([17000000, 13000000, 6000000])

# %%
city_info_df = pd.DataFrame({'City': cities, 'Population': population})

# %%
type(city_info_df)
# Out:
# pandas.core.frame.DataFrame

# %%
city_info_df
# Out:
#         City  Population
# 0     Mumbai  17000000.0
# 1  Bangalore  13000000.0
# 2    Chennai   6000000.0
# 3      Delhi         NaN

# %% [markdown]
# # Exploring data in dataframe

# %% [markdown]
# Find out the number of rows and columns in the dataframe.

# %%
df.shape
# Out:
# (442, 10)

# %% [markdown]
# In this case, there are 442 rows and 10 columns.

# %% [markdown]
# Let's see the names of the columns

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %%
list(df.columns)
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %% [markdown]
# Quickly examine a few entries in the dataframe.  Say first 5 and last 5.

# %%
? df.head

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
df.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064

# %% [markdown]
# Let's get summary statistics on the dataframe

# %%
df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260971e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324559e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947171e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243232e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335973e-01  1.356118e-01

# %%
df.describe(percentiles=[0.2, 0.6, 0.8])
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 20%   -4.547248e-02 -4.464164e-02 -4.048038e-02 -4.009893e-02 -3.871969e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 60%    1.628068e-02  5.068012e-02  5.218854e-03  8.100982e-03  8.062710e-03
# 80%    4.170844e-02  5.068012e-02  4.229559e-02  4.941519e-02  3.943444e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260971e-01 -1.377672e-01
# 20%   -3.695017e-02 -3.971921e-02 -3.949338e-02 -4.117617e-02 -3.835666e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947171e-03 -1.077698e-03
# 60%    8.706873e-03  8.142084e-03 -2.592262e-03  1.255119e-02  7.206516e-03
# 80%    3.952068e-02  3.759519e-02  3.430886e-02  3.885335e-02  3.620126e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335973e-01  1.356118e-01

# %%
df.describe().T
# Out:
#      count          mean       std       min       25%       50%       75%  \
# age  442.0 -2.511817e-19  0.047619 -0.107226 -0.037299  0.005383  0.038076
# sex  442.0  1.230790e-17  0.047619 -0.044642 -0.044642 -0.044642  0.050680
# bmi  442.0 -2.245564e-16  0.047619 -0.090275 -0.034229 -0.007284  0.031248
# bp   442.0 -4.797570e-17  0.047619 -0.112399 -0.036656 -0.005670  0.035644
# s1   442.0 -1.381499e-17  0.047619 -0.126781 -0.034248 -0.004321  0.028358
# s2   442.0  3.918434e-17  0.047619 -0.115613 -0.030358 -0.003819  0.029844
# s3   442.0 -5.777179e-18  0.047619 -0.102307 -0.035117 -0.006584  0.029312
# s4   442.0 -9.042540e-18  0.047619 -0.076395 -0.039493 -0.002592  0.034309
# s5   442.0  9.293722e-17  0.047619 -0.126097 -0.033246 -0.001947  0.032432
# s6   442.0  1.130318e-17  0.047619 -0.137767 -0.033179 -0.001078  0.027917
#
#           max
# age  0.110727
# sex  0.050680
# bmi  0.170555
# bp   0.132044
# s1   0.153914
# s2   0.198788
# s3   0.181179
# s4   0.185234
# s5   0.133597
# s6   0.135612

# %% [markdown]
# ## Selection

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %%
df['age']
# Out:
# 0      0.038076
# 1     -0.001882
# 2      0.085299
# 3     -0.089063
# 4      0.005383
#          ...
# 437    0.041708
# 438   -0.005515
# 439    0.041708
# 440   -0.045472
# 441   -0.045472
# Name: age, Length: 442, dtype: float64

# %%
type(df['age'])
# Out:
# pandas.core.series.Series

# %%
df['age'][0]
# Out:
# np.float64(0.038075906433423026)

# %%
df['age'][:5]
# Out:
# 0    0.038076
# 1   -0.001882
# 2    0.085299
# 3   -0.089063
# 4    0.005383
# Name: age, dtype: float64

# %%
df['age'][-5:]
# Out:
# 437    0.041708
# 438   -0.005515
# 439    0.041708
# 440   -0.045472
# 441   -0.045472
# Name: age, dtype: float64

# %%
df['age'][100:200]
# Out:
# 100    0.016281
# 101    0.016281
# 102   -0.092695
# 103    0.059871
# 104   -0.027310
#          ...
# 195    0.027178
# 196   -0.023677
# 197    0.048974
# 198   -0.052738
# 199    0.041708
# Name: age, Length: 100, dtype: float64

# %%
df[['age', 'sex']]
# Out:
#           age       sex
# 0    0.038076  0.050680
# 1   -0.001882 -0.044642
# 2    0.085299  0.050680
# 3   -0.089063 -0.044642
# 4    0.005383 -0.044642
# ..        ...       ...
# 437  0.041708  0.050680
# 438 -0.005515  0.050680
# 439  0.041708  0.050680
# 440 -0.045472 -0.044642
# 441 -0.045472 -0.044642
#
# [442 rows x 2 columns]

# %%
df[['age', 'sex']][:5]
# Out:
#         age       sex
# 0  0.038076  0.050680
# 1 -0.001882 -0.044642
# 2  0.085299  0.050680
# 3 -0.089063 -0.044642
# 4  0.005383 -0.044642

# %%
df[['age', 'sex']][-5:]
# Out:
#           age       sex
# 437  0.041708  0.050680
# 438 -0.005515  0.050680
# 439  0.041708  0.050680
# 440 -0.045472 -0.044642
# 441 -0.045472 -0.044642

# %%
df[['age', 'sex']]
# Out:
#           age       sex
# 0    0.038076  0.050680
# 1   -0.001882 -0.044642
# 2    0.085299  0.050680
# 3   -0.089063 -0.044642
# 4    0.005383 -0.044642
# ..        ...       ...
# 437  0.041708  0.050680
# 438 -0.005515  0.050680
# 439  0.041708  0.050680
# 440 -0.045472 -0.044642
# 441 -0.045472 -0.044642
#
# [442 rows x 2 columns]

# %% [markdown]
# * ```.loc```
# * ```.iloc```

# %%
df.iloc[441]
# Out:
# age   -0.045472
# sex   -0.044642
# bmi   -0.073030
# bp    -0.081413
# s1     0.083740
# s2     0.027809
# s3     0.173816
# s4    -0.039493
# s5    -0.004222
# s6     0.003064
# Name: 441, dtype: float64

# %%
df.iloc[0]
# Out:
# age    0.038076
# sex    0.050680
# bmi    0.061696
# bp     0.021872
# s1    -0.044223
# s2    -0.034821
# s3    -0.043401
# s4    -0.002592
# s5     0.019907
# s6    -0.017646
# Name: 0, dtype: float64

# %%
df.loc[0]
# Out:
# age    0.038076
# sex    0.050680
# bmi    0.061696
# bp     0.021872
# s1    -0.044223
# s2    -0.034821
# s3    -0.043401
# s4    -0.002592
# s5     0.019907
# s6    -0.017646
# Name: 0, dtype: float64

# %%
df.head(n=5)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
df.loc[4, 'age']
# Out:
# np.float64(0.005383060374248237)

# %%
df.loc[4, ['age', 'sex']]
# Out:
# age    0.005383
# sex   -0.044642
# Name: 4, dtype: float64

# %%
df.iloc[4, [1, 5, 7, 9]]
# Out:
# sex   -0.044642
# s2     0.015596
# s4    -0.002592
# s6    -0.046641
# Name: 4, dtype: float64

# %%
rows_condition_met = df.age > 5.383060e-03

# %%
df.loc[rows_condition_met]
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 7    0.063504  0.050680 -0.001895  0.066629  0.090620  0.108914  0.022869
# 8    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# ..        ...       ...       ...       ...       ...       ...       ...
# 431  0.070769  0.050680 -0.030996  0.021872 -0.037344 -0.047034  0.033914
# 432  0.009016 -0.044642  0.055229 -0.005670  0.057597  0.044719 -0.002903
# 434  0.016281 -0.044642  0.001339  0.008101  0.005311  0.010899  0.030232
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# 2   -0.002592  0.002861 -0.025930
# 4   -0.002592 -0.031988 -0.046641
# 7    0.017703 -0.035816  0.003064
# 8   -0.002592 -0.014960  0.011349
# ..        ...       ...       ...
# 431 -0.039493 -0.014960 -0.001078
# 432  0.023239  0.055686  0.106617
# 434 -0.039493 -0.045424  0.032059
# 437 -0.002592  0.031193  0.007207
# 439 -0.011080 -0.046883  0.015491
#
# [228 rows x 10 columns]

# %%
df.loc[df.age > 5.383060e-03]
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 7    0.063504  0.050680 -0.001895  0.066629  0.090620  0.108914  0.022869
# 8    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# ..        ...       ...       ...       ...       ...       ...       ...
# 431  0.070769  0.050680 -0.030996  0.021872 -0.037344 -0.047034  0.033914
# 432  0.009016 -0.044642  0.055229 -0.005670  0.057597  0.044719 -0.002903
# 434  0.016281 -0.044642  0.001339  0.008101  0.005311  0.010899  0.030232
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# 2   -0.002592  0.002861 -0.025930
# 4   -0.002592 -0.031988 -0.046641
# 7    0.017703 -0.035816  0.003064
# 8   -0.002592 -0.014960  0.011349
# ..        ...       ...       ...
# 431 -0.039493 -0.014960 -0.001078
# 432  0.023239  0.055686  0.106617
# 434 -0.039493 -0.045424  0.032059
# 437 -0.002592  0.031193  0.007207
# 439 -0.011080 -0.046883  0.015491
#
# [228 rows x 10 columns]

# %%
age_df_temp = df.loc[df.age < 5.383060e-03]

# %%
age_df_temp = df[df.age < 5.383060e-03]

# %%
age_df_temp.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6 -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 9 -0.070900 -0.044642  0.039062 -0.033213 -0.012577 -0.034508 -0.024993
#
#          s4        s5        s6
# 1 -0.039493 -0.068332 -0.092204
# 3  0.034309  0.022688 -0.009362
# 5 -0.076395 -0.041176 -0.096346
# 6 -0.039493 -0.062917 -0.038357
# 9 -0.002592  0.067737 -0.013504

# %%
age_df_temp.iloc[2]
# Out:
# age   -0.092695
# sex   -0.044642
# bmi   -0.040696
# bp    -0.019442
# s1    -0.068991
# s2    -0.079288
# s3     0.041277
# s4    -0.076395
# s5    -0.041176
# s6    -0.096346
# Name: 5, dtype: float64

# %%
age_df_temp.loc[1]
# Out:
# age   -0.001882
# sex   -0.044642
# bmi   -0.051474
# bp    -0.026328
# s1    -0.008449
# s2    -0.019163
# s3     0.074412
# s4    -0.039493
# s5    -0.068332
# s6    -0.092204
# Name: 1, dtype: float64

# %%
age_df_temp = df.loc[(df.age < 5.383060e-03) & (df.sex > -4.464164e-02 )]

# %%
age_df_temp.shape
# Out:
# (214, 10)

# %%
age_df_temp
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6   -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 9   -0.070900 -0.044642  0.039062 -0.033213 -0.012577 -0.034508 -0.024993
# ..        ...       ...       ...       ...       ...       ...       ...
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 436 -0.056370 -0.044642 -0.074108 -0.050427 -0.024960 -0.047034  0.092820
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 1   -0.039493 -0.068332 -0.092204
# 3    0.034309  0.022688 -0.009362
# 5   -0.076395 -0.041176 -0.096346
# 6   -0.039493 -0.062917 -0.038357
# 9   -0.002592  0.067737 -0.013504
# ..        ...       ...       ...
# 435 -0.002592 -0.038460 -0.038357
# 436 -0.076395 -0.061176 -0.046641
# 438  0.034309 -0.018114  0.044485
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064
#
# [214 rows x 10 columns]

# %%
list("ABCD")
# Out:
# ['A', 'B', 'C', 'D']

# %%
list("abcdefghi")
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

# %%
range(100)
# Out:
# range(0, 100)

# %%
import numpy as np

# %%
another_df = pd.DataFrame(
    np.random.rand(100, 4),
    index=range(10, 110),
    columns=list("ABCD"))

# %%
another_df.head()
# Out:
#            A         B         C         D
# 10  0.237176  0.360989  0.246314  0.851056
# 11  0.905223  0.243344  0.787009  0.662606
# 12  0.322834  0.519817  0.926146  0.153433
# 13  0.361995  0.100800  0.560576  0.276387
# 14  0.782064  0.237510  0.698589  0.401085

# %%
another_df.tail()
# Out:
#             A         B         C         D
# 105  0.014040  0.096844  0.662218  0.293402
# 106  0.417199  0.593230  0.425981  0.471871
# 107  0.140898  0.209326  0.673931  0.672601
# 108  0.758527  0.917995  0.845775  0.524115
# 109  0.316258  0.920810  0.463272  0.392318

# %%
df = pd.DataFrame(np.random.rand(9, 4), index=list("abcdefghi"), columns=list("ABCD"))

# %%
df.shape
# Out:
# (9, 4)

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, a to i
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       9 non-null      float64
#  1   B       9 non-null      float64
#  2   C       9 non-null      float64
#  3   D       9 non-null      float64
# dtypes: float64(4)
# memory usage: 360.0+ bytes

# %%
df.head()
# Out:
#           A         B         C         D
# a  0.241597  0.915374  0.991589  0.889295
# b  0.570384  0.501068  0.837986  0.526060
# c  0.370625  0.897892  0.394549  0.195513
# d  0.909647  0.534820  0.569171  0.301634
# e  0.376796  0.524866  0.780062  0.481208

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i'], dtype='object')

# %%
df.loc['a']
# Out:
# A    0.241597
# B    0.915374
# C    0.991589
# D    0.889295
# Name: a, dtype: float64

# %%
df.loc['a', 'A':'D']
# Out:
# A    0.241597
# B    0.915374
# C    0.991589
# D    0.889295
# Name: a, dtype: float64

# %%
df.loc['a':'d', :]
# Out:
#           A         B         C         D
# a  0.241597  0.915374  0.991589  0.889295
# b  0.570384  0.501068  0.837986  0.526060
# c  0.370625  0.897892  0.394549  0.195513
# d  0.909647  0.534820  0.569171  0.301634

# %%
df.iloc[:4, 0:3]
# Out:
#           A         B         C
# a  0.241597  0.915374  0.991589
# b  0.570384  0.501068  0.837986
# c  0.370625  0.897892  0.394549
# d  0.909647  0.534820  0.569171

# %%
df.iloc[:4, 1:3]
# Out:
#           B         C
# a  0.915374  0.991589
# b  0.501068  0.837986
# c  0.897892  0.394549
# d  0.534820  0.569171

# %%
df.iloc[0:4, :]
# Out:
#           A         B         C         D
# a  0.241597  0.915374  0.991589  0.889295
# b  0.570384  0.501068  0.837986  0.526060
# c  0.370625  0.897892  0.394549  0.195513
# d  0.909647  0.534820  0.569171  0.301634

# %%
df.iloc[0:4]
# Out:
#           A         B         C         D
# a  0.241597  0.915374  0.991589  0.889295
# b  0.570384  0.501068  0.837986  0.526060
# c  0.370625  0.897892  0.394549  0.195513
# d  0.909647  0.534820  0.569171  0.301634

# %%
df.iloc[:, 1]
# Out:
# a    0.915374
# b    0.501068
# c    0.897892
# d    0.534820
# e    0.524866
# f    0.866207
# g    0.175137
# h    0.206817
# i    0.130429
# Name: B, dtype: float64

# %%
selector = lambda df: df['A'] > 0

# %%
selector
# Out:
# <function __main__.<lambda>(df)>

# %%
df.loc[selector]
# Out:
#           A         B         C         D
# a  0.241597  0.915374  0.991589  0.889295
# b  0.570384  0.501068  0.837986  0.526060
# c  0.370625  0.897892  0.394549  0.195513
# d  0.909647  0.534820  0.569171  0.301634
# e  0.376796  0.524866  0.780062  0.481208
# f  0.105346  0.866207  0.855253  0.708715
# g  0.452201  0.175137  0.604182  0.638627
# h  0.760221  0.206817  0.465413  0.767832
# i  0.735145  0.130429  0.838723  0.150257

# %%
selector = lambda df: df['A'] > 0.5

# %%
df.loc[selector]
# Out:
#           A         B         C         D
# b  0.570384  0.501068  0.837986  0.526060
# d  0.909647  0.534820  0.569171  0.301634
# h  0.760221  0.206817  0.465413  0.767832
# i  0.735145  0.130429  0.838723  0.150257

# %%
selector = lambda df: (df['A'] > 0.5)&(df['B'] < 0.2)

# %%
df.loc[selector]
# Out:
#           A         B         C         D
# i  0.735145  0.130429  0.838723  0.150257

# %%
condition_for_selection = (df['A'] > 0.5)&(df['B'] < 0.2)

# %%
condition_for_selection
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# f    False
# g    False
# h    False
# i     True
# dtype: bool

# %%
df[condition_for_selection]
# Out:
#           A         B         C         D
# i  0.735145  0.130429  0.838723  0.150257

# %%
condition_for_selection = (df['A'] > 0.5) | ~(df['B'] < 0.2)

# %%
df[condition_for_selection]
# Out:
#           A         B         C         D
# a  0.241597  0.915374  0.991589  0.889295
# b  0.570384  0.501068  0.837986  0.526060
# c  0.370625  0.897892  0.394549  0.195513
# d  0.909647  0.534820  0.569171  0.301634
# e  0.376796  0.524866  0.780062  0.481208
# f  0.105346  0.866207  0.855253  0.708715
# h  0.760221  0.206817  0.465413  0.767832
# i  0.735145  0.130429  0.838723  0.150257

# %% [markdown]
# OR operator: |
# NOT operator: ~

# %% [markdown]
# ## Adding a column in the dataframe

# %%
df['E'] = df['A']*100

# %%
df
# Out:
#           A         B         C         D          E
# a  0.241597  0.915374  0.991589  0.889295  24.159727
# b  0.570384  0.501068  0.837986  0.526060  57.038439
# c  0.370625  0.897892  0.394549  0.195513  37.062480
# d  0.909647  0.534820  0.569171  0.301634  90.964745
# e  0.376796  0.524866  0.780062  0.481208  37.679606
# f  0.105346  0.866207  0.855253  0.708715  10.534598
# g  0.452201  0.175137  0.604182  0.638627  45.220092
# h  0.760221  0.206817  0.465413  0.767832  76.022077
# i  0.735145  0.130429  0.838723  0.150257  73.514547

# %%
df["F"] = df["A"] + df["C"]

# %%
df
# Out:
#           A         B         C         D          E         F
# a  0.241597  0.915374  0.991589  0.889295  24.159727  1.233186
# b  0.570384  0.501068  0.837986  0.526060  57.038439  1.408370
# c  0.370625  0.897892  0.394549  0.195513  37.062480  0.765174
# d  0.909647  0.534820  0.569171  0.301634  90.964745  1.478818
# e  0.376796  0.524866  0.780062  0.481208  37.679606  1.156858
# f  0.105346  0.866207  0.855253  0.708715  10.534598  0.960599
# g  0.452201  0.175137  0.604182  0.638627  45.220092  1.056383
# h  0.760221  0.206817  0.465413  0.767832  76.022077  1.225634
# i  0.735145  0.130429  0.838723  0.150257  73.514547  1.573869

# %%
criteria = df['A'] < 0.2

# %%
criteria
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# f     True
# g    False
# h    False
# i    False
# Name: A, dtype: bool

# %%
df.loc[criteria, 'A'] = 0

# %%
df
# Out:
#           A         B         C         D          E         F
# a  0.241597  0.915374  0.991589  0.889295  24.159727  1.233186
# b  0.570384  0.501068  0.837986  0.526060  57.038439  1.408370
# c  0.370625  0.897892  0.394549  0.195513  37.062480  0.765174
# d  0.909647  0.534820  0.569171  0.301634  90.964745  1.478818
# e  0.376796  0.524866  0.780062  0.481208  37.679606  1.156858
# f  0.000000  0.866207  0.855253  0.708715  10.534598  0.960599
# g  0.452201  0.175137  0.604182  0.638627  45.220092  1.056383
# h  0.760221  0.206817  0.465413  0.767832  76.022077  1.225634
# i  0.735145  0.130429  0.838723  0.150257  73.514547  1.573869

# %%
cities = ['Mumbai', 'Delhi', 'Chennai', 'Kolkata', 'Bengalure', 'Hyderabad', 'Pune', 'Ahmedabad', 'Indore']

# %%
df['city'] = cities

# %%
df_copy = df.copy()

# %%
df
# Out:
#           A         B         C         D          E         F       city
# a  0.241597  0.915374  0.991589  0.889295  24.159727  1.233186     Mumbai
# b  0.570384  0.501068  0.837986  0.526060  57.038439  1.408370      Delhi
# c  0.370625  0.897892  0.394549  0.195513  37.062480  0.765174    Chennai
# d  0.909647  0.534820  0.569171  0.301634  90.964745  1.478818    Kolkata
# e  0.376796  0.524866  0.780062  0.481208  37.679606  1.156858  Bengalure
# f  0.000000  0.866207  0.855253  0.708715  10.534598  0.960599  Hyderabad
# g  0.452201  0.175137  0.604182  0.638627  45.220092  1.056383       Pune
# h  0.760221  0.206817  0.465413  0.767832  76.022077  1.225634  Ahmedabad
# i  0.735145  0.130429  0.838723  0.150257  73.514547  1.573869     Indore

# %%
cities_new = ['Mumbai', 'Delhi', 'Chennai',
              'Kolkata', 'Bengalure', 'Hyderabad',
              'Pune', 'Ahmedabad', 'Guwahati']

# %%
df_copy['new_city'] = cities_new

# %%
df_copy
# Out:
#           A         B         C         D          E         F       city  \
# a  0.241597  0.915374  0.991589  0.889295  24.159727  1.233186     Mumbai
# b  0.570384  0.501068  0.837986  0.526060  57.038439  1.408370      Delhi
# c  0.370625  0.897892  0.394549  0.195513  37.062480  0.765174    Chennai
# d  0.909647  0.534820  0.569171  0.301634  90.964745  1.478818    Kolkata
# e  0.376796  0.524866  0.780062  0.481208  37.679606  1.156858  Bengalure
# f  0.000000  0.866207  0.855253  0.708715  10.534598  0.960599  Hyderabad
# g  0.452201  0.175137  0.604182  0.638627  45.220092  1.056383       Pune
# h  0.760221  0.206817  0.465413  0.767832  76.022077  1.225634  Ahmedabad
# i  0.735145  0.130429  0.838723  0.150257  73.514547  1.573869     Indore
#
#     new_city
# a     Mumbai
# b      Delhi
# c    Chennai
# d    Kolkata
# e  Bengalure
# f  Hyderabad
# g       Pune
# h  Ahmedabad
# i   Guwahati

# %%
criteria = df_copy['city'].isin(['Pune', 'Bengaluru', 'Hyderabad'])

# %%
df_copy.loc[df.city == 'Bengalure', ['city', 'new_city']] = 'Bengaluru'

# %%
df_copy
# Out:
#           A         B         C         D          E         F       city  \
# a  0.241597  0.915374  0.991589  0.889295  24.159727  1.233186     Mumbai
# b  0.570384  0.501068  0.837986  0.526060  57.038439  1.408370      Delhi
# c  0.370625  0.897892  0.394549  0.195513  37.062480  0.765174    Chennai
# d  0.909647  0.534820  0.569171  0.301634  90.964745  1.478818    Kolkata
# e  0.376796  0.524866  0.780062  0.481208  37.679606  1.156858  Bengaluru
# f  0.000000  0.866207  0.855253  0.708715  10.534598  0.960599  Hyderabad
# g  0.452201  0.175137  0.604182  0.638627  45.220092  1.056383       Pune
# h  0.760221  0.206817  0.465413  0.767832  76.022077  1.225634  Ahmedabad
# i  0.735145  0.130429  0.838723  0.150257  73.514547  1.573869     Indore
#
#     new_city
# a     Mumbai
# b      Delhi
# c    Chennai
# d    Kolkata
# e  Bengaluru
# f  Hyderabad
# g       Pune
# h  Ahmedabad
# i   Guwahati

# %%
# ?df_copy.drop

# %%
df_copy.drop(['new_cities'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-311/119092824.py in <cell line: 0>()
# ----> 1 df_copy.drop(['new_cities'], axis=1)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['new_cities'] not found in axis"

# %%
criteria

# %%
df_copy.loc[:, 'city'] = 'Chennai'

# %%
df_copy = df_copy.drop(['new_cities'], axis=1)

# %%
df_copy

# %%
df_copy = df_copy.drop(['city'])

# %%
df_copy

# %%
# ?df_copy.sample

# %%
df_copy.sample(3)

# %%
df_copy.sample(3)

# %%
df_copy.sample(3, random_state=42)

# %%
df_copy.sample(3, random_state=42)
# Out:
#           A         B         C         D          E         F       city  \
# h  0.760221  0.206817  0.465413  0.767832  76.022077  1.225634  Ahmedabad
# b  0.570384  0.501068  0.837986  0.526060  57.038439  1.408370      Delhi
# f  0.000000  0.866207  0.855253  0.708715  10.534598  0.960599  Hyderabad
#
#     new_city
# h  Ahmedabad
# b      Delhi
# f  Hyderabad

# %%
df_copy.sample(3, random_state=42, replace=True)
# Out:
#           A         B         C         D          E         F       city  \
# g  0.452201  0.175137  0.604182  0.638627  45.220092  1.056383       Pune
# d  0.909647  0.534820  0.569171  0.301634  90.964745  1.478818    Kolkata
# h  0.760221  0.206817  0.465413  0.767832  76.022077  1.225634  Ahmedabad
#
#     new_city
# g       Pune
# d    Kolkata
# h  Ahmedabad

# %%
import pandas as pd

cities = ['Mumbai', 'Chennai', 'Pune', 'Ahmedabad', 'Kolkata', 'Kanpur', 'Delhi']
city_df = pd.DataFrame(cities)

# %%
city_df.columns = ['City_Name']

# %%
city_df
# Out:
#    City_Name
# 0     Mumbai
# 1    Chennai
# 2       Pune
# 3  Ahmedabad
# 4    Kolkata
# 5     Kanpur
# 6      Delhi

# %%
condition_met = city_df.City_Name == 'Mumbai'

# %%
type(condition_met)
# Out:
# pandas.core.series.Series

# %%
city_df[condition_met]
# Out:
#   City_Name
# 0    Mumbai

# %%
condition_met
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# Name: City_Name, dtype: bool

# %%
city_df[city_df.City_Name == 'Pune']
# Out:
#   City_Name
# 2      Pune

# %% [markdown]
# Pandas [cheatsheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)

# %% [markdown]
# # Agggregation and grouping

# %%
import numpy as np

# %%
random_state = np.random.RandomState(100)
random_series = pd.Series(random_state.rand(10))

# %%
random_series
# Out:
# 0    0.543405
# 1    0.278369
# 2    0.424518
# 3    0.844776
# 4    0.004719
# 5    0.121569
# 6    0.670749
# 7    0.825853
# 8    0.136707
# 9    0.575093
# dtype: float64

# %% [markdown]
# Now that the series is created, we can try aggregation functions like `mean`, `std` etc.

# %%
random_series.mean()
# Out:
# np.float64(0.4425757785871915)

# %%
random_series.std()
# Out:
# 0.2988992029497061

# %%
random_series.sum()
# Out:
# np.float64(4.425757785871915)

# %% [markdown]
# Let's create a dataframe with 5 rows and 2 columns containing random numbers.

# %%
df = pd.DataFrame({'A': random_state.rand(5),
                   'B': random_state.rand(5)})
df
# Out:
#           A         B
# 0  0.891322  0.978624
# 1  0.209202  0.811683
# 2  0.185328  0.171941
# 3  0.108377  0.816225
# 4  0.219697  0.274074

# %%
df.sum()
# Out:
# A    1.613927
# B    3.052546
# dtype: float64

# %%
df.mean()
# Out:
# A    0.322785
# B    0.610509
# dtype: float64

# %% [markdown]
# Try these operations row-wise

# %%
df.mean(axis=1)
# Out:
# 0    0.934973
# 1    0.510443
# 2    0.178635
# 3    0.462301
# 4    0.246886
# dtype: float64

# %%
df.sum(axis=1)
# Out:
# 0    1.869946
# 1    1.020885
# 2    0.357269
# 3    0.924602
# 4    0.493771
# dtype: float64

# %% [markdown]
# ## Groupby
#
# Three stages
# * Split - we split dataframe into multiple smaller dataframe based on the values of keys
# * Apply - we apply desired aggregation/transformation on each dataframe.
# * Combine - we combine results from apply state into a dataframe
#
# ![split-apply-combine.png](data:image/png;base64,...)

# %%
list("ABCABC")
# Out:
# ['A', 'B', 'C', 'A', 'B', 'C']

# %%
df = pd.DataFrame({'key': ['A','B','C']*2, #list("ABCABC"), ['A','B','C','A','B','C']
                   'data': range(6)})

# %%
df
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   A     3
# 4   B     4
# 5   C     5

# %%
df.groupby("key")

# %%
df.groupby("key").sum()
# Out:
#      data
# key
# A       3
# B       5
# C       7
